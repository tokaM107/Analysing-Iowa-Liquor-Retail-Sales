# %% [markdown]
# # **Analyzing "Iowa Liquor Retail Sales"**

# %% [markdown]
# # Step 1: Import Libraries and Explore the Dataset
#
# ## **Objectives**
# - Load the dataset and examine its structure.
# - Check the first few rows of the data.
# - Assess the column data types and summary statistics.
# - Identify any missing values.
#
# ## **Code**

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/tokamohamed/Documents/final-project-444323-70e7c50e4cc5.json"

# %%
# Import required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Initialize BigQuery client (if working with BigQuery)
from google.cloud import bigquery
from google.cloud import bigquery

client = bigquery.Client()

# %%
# !pip install google-cloud-bigquery
# Out:
# Requirement already satisfied: google-cloud-bigquery in /opt/homebrew/lib/python3.11/site-packages (3.27.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.11.1 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.32.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.7.2)
# Requirement already satisfied: packaging>=20.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (23.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.8.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.31.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (1.63.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (1.24.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (1.62.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from google-resumable-media<3.0dev,>=2.0.0->google-cloud-bigquery) (1.6.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2024.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (0.6.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# !pip install --upgrade google-cloud-bigquery
# Out:
# Requirement already satisfied: google-cloud-bigquery in /opt/homebrew/lib/python3.11/site-packages (3.27.0)
# Collecting google-cloud-bigquery
#   Downloading google_cloud_bigquery-3.31.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.32.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.7.2)
# Collecting packaging>=24.2.0 (from google-cloud-bigquery)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery) (2.31.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.63.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.24.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.62.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.6.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2024.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.0)
# Downloading google_cloud_bigquery-3.31.0-py3-none-any.whl (250 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Installing collected packages: packaging, google-cloud-bigquery
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 3.27.0
#     Uninstalling google-cloud-bigquery-3.27.0:
#       Successfully uninstalled google-cloud-bigquery-3.27.0
# Successfully installed google-cloud-bigquery-3.31.0 packaging-24.2
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# Corrected query with valid column names
query = """
  SELECT *
FROM `bigquery-public-data.iowa_liquor_sales.sales`
WHERE date BETWEEN '2020-01-01' AND '2024-11-29'
ORDER BY RAND()
LIMIT 30000;

"""
query_job = client.query(query)
# Convert query results into a dictionary
results = query_job.result()  # This fetches all the rows from the query

# %%
# Load it directly into a pandas DataFrame
df = pd.DataFrame([dict(row) for row in results])

# %%
df.head()
# Out:
#   invoice_and_item_number        date store_number  \
# 0         INV-35341200018  2021-03-26         4334
# 1         INV-68950900010  2024-04-05        10199
# 2         INV-75085400126  2024-10-09         2590
# 3         INV-40950900073  2021-10-13         2642
# 4         INV-28428000041  2020-07-01         2285
#
#                             store_name                 address          city  \
# 0        FAREWAY STORES #114 / DUBUQUE  2050 JOHN F KENNEDY RD       DUBUQUE
# 1           ELKADER PIT STOP / ELKADER        200 W BRIDGE ST.       ELKADER
# 2  HY-VEE FOOD STORE #5 / CEDAR RAPIDS    3235 OAKLAND ROAD NE  CEDAR RAPIDS
# 3      HY-VEE WINE AND SPIRITS / PELLA         512 E OSKALOOSA         PELLA
# 4                       JOHN'S GROCERY      401 EAST MARKET ST     IOWA CITY
#
#   zip_code                     store_location county_number   county  ...  \
# 0  52001.0                               None            31  DUBUQUE  ...
# 1  52043.0  POINT(-91.405843017 42.854053016)          None  CLAYTON  ...
# 2  52402.0          POINT(-91.65919 42.01149)          None     LINN  ...
# 3  50219.0        POINT(-92.899277 41.396961)            63   MARION  ...
# 4    52240        POINT(-91.529854 41.663541)            52  JOHNSON  ...
#
#   item_number             item_description pack bottle_volume_ml  \
# 0       52318        CHRISTIAN BROS BRANDY    6             1750
# 1       34006  ABSOLUT SWEDISH VODKA 80PRF   12              750
# 2       54446     PARAMOUNT APRICOT BRANDY   12              750
# 3       86990        CEDAR RIDGE SIR MAPLE    6              750
# 4       28238          BOMBAY SAPPHIRE GIN    6             1750
#
#   state_bottle_cost state_bottle_retail  bottles_sold  sale_dollars  \
# 0             12.00               18.00             6        107.94
# 1              9.99               14.99             2         29.98
# 2              5.75                8.63             3         25.89
# 3             23.00               34.50             6        207.00
# 4             26.50               39.75            18        715.50
#
#    volume_sold_liters  volume_sold_gallons
# 0               10.50                 2.77
# 1                1.50                 0.39
# 2                2.25                 0.59
# 3                4.50                 1.18
# 4               31.50                 8.32
#
# [5 rows x 24 columns]

# %%
# [
#   {
#     "name": "invoice_and_item_number",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Concatenated invoice and line number associated with the liquor order. This provides a unique identifier for the individual liquor products included in the store order.",
#     "fields": []
#   },
#   {
#     "name": "date",
#     "mode": "NULLABLE",
#     "type": "DATE",
#     "description": "Date of order",
#     "fields": []
#   },
#   {
#     "name": "store_number",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Unique number assigned to the store who ordered the liquor.",
#     "fields": []
#   },
#   {
#     "name": "store_name",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Name of store who ordered the liquor.",
#     "fields": []
#   },
#   {
#     "name": "address",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Address of store who ordered the liquor.",
#     "fields": []
#   },
#   {
#     "name": "city",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "City where the store who ordered the liquor is located",
#     "fields": []
#   },
#   {
#     "name": "zip_code",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Zip code where the store who ordered the liquor is located",
#     "fields": []
#   },
#   {
#     "name": "store_location",
#     "mode": "NULLABLE",
#     "type": "GEOGRAPHY",
#     "description": "Location of store who ordered the liquor. The Address, City, State and Zip Code are geocoded to provide geographic coordinates. Accuracy of geocoding is dependent on how well the address is interpreted and the completeness of the reference data used.",
#     "fields": []
#   },
#   {
#     "name": "county_number",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Iowa county number for the county where store who ordered the liquor is located",
#     "fields": []
#   },
#   {
#     "name": "county",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "County where the store who ordered the liquor is located",
#     "fields": []
#   },
#   {
#     "name": "category",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Category code associated with the liquor ordered",
#     "fields": []
#   },
#   {
#     "name": "category_name",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Category of the liquor ordered.",
#     "fields": []
#   },
#   {
#     "name": "vendor_number",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "The vendor number of the company for the brand of liquor ordered",
#     "fields": []
#   },
#   {
#     "name": "vendor_name",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "The vendor name of the company for the brand of liquor ordered",
#     "fields": []
#   },
#   {
#     "name": "item_number",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Item number for the individual liquor product ordered.",
#     "fields": []
#   },
#   {
#     "name": "item_description",
#     "mode": "NULLABLE",
#     "type": "STRING",
#     "description": "Description of the individual liquor product ordered.",
#     "fields": []
#   },
#   {
#     "name": "pack",
#     "mode": "NULLABLE",
#     "type": "INTEGER",
#     "description": "The number of bottles in a case for the liquor ordered",
#     "fields": []
#   },
#   {
#     "name": "bottle_volume_ml",
#     "mode": "NULLABLE",
#     "type": "INTEGER",
#     "description": "Volume of each liquor bottle ordered in milliliters.",
#     "fields": []
#   },
#   {
#     "name": "state_bottle_cost",
#     "mode": "NULLABLE",
#     "type": "FLOAT",
#     "description": "The amount that Alcoholic Beverages Division paid for each bottle of liquor ordered",
#     "fields": []
#   },
#   {
#     "name": "state_bottle_retail",
#     "mode": "NULLABLE",
#     "type": "FLOAT",
#     "description": "The amount the store paid for each bottle of liquor ordered",
#     "fields": []
#   },
#   {
#     "name": "bottles_sold",
#     "mode": "NULLABLE",
#     "type": "INTEGER",
#     "description": "The number of bottles of liquor ordered by the store",
#     "fields": []
#   },
#   {
#     "name": "sale_dollars",
#     "mode": "NULLABLE",
#     "type": "FLOAT",
#     "description": "Total cost of liquor order (number of bottles multiplied by the state bottle retail)",
#     "fields": []
#   },
#   {
#     "name": "volume_sold_liters",
#     "mode": "NULLABLE",
#     "type": "FLOAT",
#     "description": "Total volume of liquor ordered in liters. (i.e. (Bottle Volume (ml) x Bottles Sold)/1,000)\"",
#     "fields": []
#   },
#   {
#     "name": "volume_sold_gallons",
#     "mode": "NULLABLE",
#     "type": "FLOAT",
#     "description": "Total volume of liquor ordered in gallons. (i.e. (Bottle Volume (ml) x Bottles Sold)/3785.411784)\"",
#     "fields": []
#   }
# ]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   invoice_and_item_number  30000 non-null  object
#  1   date                     30000 non-null  object
#  2   store_number             30000 non-null  object
#  3   store_name               30000 non-null  object
#  4   address                  29994 non-null  object
#  5   city                     29994 non-null  object
#  6   zip_code                 29994 non-null  object
#  7   store_location           28115 non-null  object
#  8   county_number            15278 non-null  object
#  9   county                   29994 non-null  object
#  10  category                 29998 non-null  object
#  11  category_name            29998 non-null  object
#  12  vendor_number            30000 non-null  object
#  13  vendor_name              30000 non-null  object
#  14  item_number              30000 non-null  object
#  15  item_description         30000 non-null  object
#  16  pack                     30000 non-null  int64
#  17  bottle_volume_ml         30000 non-null  int64
#  18  state_bottle_cost        30000 non-null  float64
#  19  state_bottle_retail      30000 non-null  float64
#  20  bottles_sold             30000 non-null  int64
#  21  sale_dollars             30000 non-null  float64
#  22  volume_sold_liters       30000 non-null  float64
#  23  volume_sold_gallons      30000 non-null  float64
# dtypes: float64(5), int64(3), object(16)
# memory usage: 5.5+ MB

# %%
df.describe()
# Out:
#                pack  bottle_volume_ml  state_bottle_cost  state_bottle_retail  \
# count  30000.000000      30000.000000       30000.000000         30000.000000
# mean      11.815000        808.085167          12.311317            18.468631
# std        8.042756        524.647688          16.379102            24.568690
# min        1.000000         20.000000           0.890000             1.340000
# 25%        6.000000        375.000000           6.000000             9.000000
# 50%       12.000000        750.000000           9.250000            13.880000
# 75%       12.000000       1000.000000          15.000000            22.500000
# max       60.000000       4500.000000        2000.000000          3000.000000
#
#        bottles_sold  sale_dollars  volume_sold_liters  volume_sold_gallons
# count  30000.000000  30000.000000        30000.000000         30000.000000
# mean      11.831367    165.371450            9.253483             2.438836
# std       29.861460    497.321087           37.140490             9.811705
# min      -12.000000   -336.120000          -21.000000            -5.540000
# 25%        3.000000     44.700000            1.500000             0.390000
# 50%        6.000000     90.000000            4.500000             1.180000
# 75%       12.000000    168.060000           10.500000             2.770000
# max     1350.000000  18803.400000         2362.500000           624.100000

# %%
df.nunique()
# Out:
# invoice_and_item_number    30000
# date                        1355
# store_number                2233
# store_name                  2280
# address                     2281
# city                         450
# zip_code                     851
# store_location              6064
# county_number                 99
# county                        99
# category                      53
# category_name                 44
# vendor_number                237
# vendor_name                  177
# item_number                 3157
# item_description            2605
# pack                          16
# bottle_volume_ml              19
# state_bottle_cost           1065
# state_bottle_retail         1067
# bottles_sold                  82
# sale_dollars                3535
# volume_sold_liters           179
# volume_sold_gallons          177
# dtype: int64

# %% [markdown]
# # Step 2: Data Cleaning

# %% [markdown]
# 1. Check the missing values

# %%
df.isnull().sum()
# Out:
# invoice_and_item_number        0
# date                           0
# store_number                   0
# store_name                     0
# address                        6
# city                           6
# zip_code                       6
# store_location              1885
# county_number              14722
# county                         6
# category                       2
# category_name                  2
# vendor_number                  0
# vendor_name                    0
# item_number                    0
# item_description               0
# pack                           0
# bottle_volume_ml               0
# state_bottle_cost              0
# state_bottle_retail            0
# bottles_sold                   0
# sale_dollars                   0
# volume_sold_liters             0
# volume_sold_gallons            0
# dtype: int64

# %%
df.drop(['county_number','store_location'], axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29992 entries, 0 to 29999
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   invoice_and_item_number  29992 non-null  object
#  1   date                     29992 non-null  object
#  2   store_number             29992 non-null  object
#  3   store_name               29992 non-null  object
#  4   address                  29992 non-null  object
#  5   city                     29992 non-null  object
#  6   zip_code                 29992 non-null  object
#  7   county                   29992 non-null  object
#  8   category                 29992 non-null  object
#  9   category_name            29992 non-null  object
#  10  vendor_number            29992 non-null  object
#  11  vendor_name              29992 non-null  object
#  12  item_number              29992 non-null  object
#  13  item_description         29992 non-null  object
#  14  pack                     29992 non-null  int64
#  15  bottle_volume_ml         29992 non-null  int64
#  16  state_bottle_cost        29992 non-null  float64
#  17  state_bottle_retail      29992 non-null  float64
#  18  bottles_sold             29992 non-null  int64
#  19  sale_dollars             29992 non-null  float64
#  20  volume_sold_liters       29992 non-null  float64
#  21  volume_sold_gallons      29992 non-null  float64
# dtypes: float64(5), int64(3), object(14)
# memory usage: 5.3+ MB

# %% [markdown]
# 2. Check the duplicates

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# ##### 3. Feature extraction

# %%
df['date']= pd.to_datetime(df['date'])
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month

# %% [markdown]
# 4. remove unnececarry columns

# %%
df.drop(['date','invoice_and_item_number','address','city','zip_code','category','vendor_number','item_number','item_description','volume_sold_gallons'], axis=1 , inplace=True)

# %% [markdown]
# 3. Handling the Data Types

# %%
df['store_number'] = pd.to_numeric(df['store_number'], errors='coerce')

# %%
df.dtypes
# Out:
# store_number             int64
# store_name              object
# county                  object
# category_name           object
# vendor_name             object
# pack                     int64
# bottle_volume_ml         int64
# state_bottle_cost      float64
# state_bottle_retail    float64
# bottles_sold             int64
# sale_dollars           float64
# volume_sold_liters     float64
# year                     int32
# month                    int32
# dtype: object

# %% [markdown]
# 4. Addressing Outliers or Anomalies

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'store_number'}>,
#         <Axes: title={'center': 'pack'}>,
#         <Axes: title={'center': 'bottle_volume_ml'}>],
#        [<Axes: title={'center': 'state_bottle_cost'}>,
#         <Axes: title={'center': 'state_bottle_retail'}>,
#         <Axes: title={'center': 'bottles_sold'}>],
#        [<Axes: title={'center': 'sale_dollars'}>,
#         <Axes: title={'center': 'volume_sold_liters'}>,
#         <Axes: title={'center': 'year'}>],
#        [<Axes: title={'center': 'month'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
df[['state_bottle_cost', 'state_bottle_retail', 'bottles_sold']].boxplot()
plt.show()

# %% [markdown]
# 5. Cleaning Up Invalid or Inconsistent Entries

# %%
df.describe()
# Out:
#        store_number          pack  bottle_volume_ml  state_bottle_cost  \
# count  29992.000000  29992.000000      29992.000000       29992.000000
# mean    4359.252234     11.814084        808.143338          12.311732
# std     1667.292894      8.041611        524.685528          16.381008
# min     2106.000000      1.000000         20.000000           0.890000
# 25%     2647.000000      6.000000        375.000000           6.000000
# 50%     4260.000000     12.000000        750.000000           9.250000
# 75%     5410.000000     12.000000       1000.000000          15.000000
# max    10506.000000     60.000000       4500.000000        2000.000000
#
#        state_bottle_retail  bottles_sold  sale_dollars  volume_sold_liters  \
# count         29992.000000  29992.000000  29992.000000        29992.000000
# mean             18.469254     11.832522    165.385685            9.254817
# std              24.571549     29.865297    497.385745           37.145317
# min               1.340000    -12.000000   -336.120000          -21.000000
# 25%               9.000000      3.000000     44.700000            1.500000
# 50%              13.880000      6.000000     90.000000            4.500000
# 75%              22.500000     12.000000    168.060000           10.500000
# max            3000.000000   1350.000000  18803.400000         2362.500000
#
#                year         month
# count  29992.000000  29992.000000
# mean    2021.959122      6.594859
# std        1.401137      3.374417
# min     2020.000000      1.000000
# 25%     2021.000000      4.000000
# 50%     2022.000000      7.000000
# 75%     2023.000000     10.000000
# max     2024.000000     12.000000

# %%
df = df[(df[['bottles_sold', 'sale_dollars', 'volume_sold_liters']] >= 0).all(axis=1)]

# %%
numeric_columns = df.select_dtypes(include=['number'])

# %%
numeric_columns.shape
# Out:
# (29975, 10)

# %% [markdown]
# # Step 3: Data Visualization
# - Create some charts, colleration matrix, heatmap, and any other additional thing you find by your search
# - Write conclusion under each of the chart

# %%
plt.figure(figsize=(10, 8))  
sns.heatmap(numeric_columns.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Step 4: Data Preprocessing
# "Search for steps suitable for the following ML algorithms"
# - Encoding categorical data.
# - Scaling or normalizing numerical features.
# - Feature engineering (e.g., creating or combining features).

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
nums = df.select_dtypes(include=['int64', 'float64']).columns

df[nums]= scaler.fit_transform(df[nums])

# %%
df
# Out:
#        store_number                                    store_name    county  \
# 0          0.265238                 FAREWAY STORES #114 / DUBUQUE   DUBUQUE
# 1          0.963452                    ELKADER PIT STOP / ELKADER   CLAYTON
# 2          0.057619           HY-VEE FOOD STORE #5 / CEDAR RAPIDS      LINN
# 3          0.063810               HY-VEE WINE AND SPIRITS / PELLA    MARION
# 4          0.021310                                JOHN'S GROCERY   JOHNSON
# ...             ...                                           ...       ...
# 29995      0.397381                    MARSHALL BEER WINE SPIRITS  MARSHALL
# 29996      0.071905                       HY-VEE GAS #1 / OTTUMWA   WAPELLO
# 29997      0.183214               WAL-MART 1764 / WINDSOR HEIGHTS      POLK
# 29998      0.408810  CASEY'S GENERAL STORE #2447 / SERGEANT BLUFF  WOODBURY
# 29999      0.408095      CASEY'S GENERAL STORE #3674 / SIOUX CITY  WOODBURY
#
#                         category_name               vendor_name      pack  \
# 0                   AMERICAN BRANDIES        HEAVEN HILL BRANDS  0.084746
# 1                     IMPORTED VODKAS         PERNOD RICARD USA  0.186441
# 2                   AMERICAN BRANDIES                 LUXCO INC  0.186441
# 3      TEMPORARY & SPECIALTY PACKAGES  CEDAR RIDGE VINEYARDS LL  0.084746
# 4                   IMPORTED DRY GINS           BACARDI USA INC  0.084746
# ...                               ...                       ...       ...
# 29995              TENNESSEE WHISKIES        BROWN FORMAN CORP.  0.186441
# 29996                  IRISH WHISKIES         PERNOD RICARD USA  0.389831
# 29997               CANADIAN WHISKIES           DIAGEO AMERICAS  0.084746
# 29998               CANADIAN WHISKIES        HEAVEN HILL BRANDS  0.186441
# 29999              TENNESSEE WHISKIES        BROWN FORMAN CORP.  0.186441
#
#        bottle_volume_ml  state_bottle_cost  state_bottle_retail  bottles_sold  \
# 0              0.386161           0.005557             0.005556      0.003706
# 1              0.162946           0.004552             0.004552      0.000741
# 2              0.162946           0.002431             0.002431      0.001483
# 3              0.162946           0.011060             0.011058      0.003706
# 4              0.386161           0.012811             0.012809      0.012602
# ...                 ...                ...                  ...           ...
# 29995          0.162946           0.007513             0.007513      0.008154
# 29996          0.079241           0.003552             0.003552      0.000741
# 29997          0.386161           0.016557             0.016557      0.003706
# 29998          0.162946           0.002171             0.002171      0.008154
# 29999          0.162946           0.007513             0.007513      0.008154
#
#        sale_dollars  volume_sold_liters  year  month
# 0          0.005651            0.004436  2021      3
# 1          0.001504            0.000626  2024      4
# 2          0.001287            0.000944  2024     10
# 3          0.010919            0.001896  2021     10
# 4          0.037965            0.013325  2020      7
# ...             ...                 ...   ...    ...
# 29995      0.015144            0.003801  2022      8
# 29996      0.001185            0.000309  2022      9
# 29997      0.016182            0.004436  2023      6
# 29998      0.004920            0.003801  2020     10
# 29999      0.015144            0.003801  2023      5
#
# [29975 rows x 14 columns]

# %%
# Frequency Encoding
for col in ['category_name', 'county', 'vendor_name']:
    freq_encoding = df[col].value_counts()
    df[col + '_freq_encoded'] = df[col].map(freq_encoding)

# %%
df.drop(['county','store_name','category_name','vendor_name'],axis=1,inplace=True)

# %%
df
# Out:
#        store_number      pack  bottle_volume_ml  state_bottle_cost  \
# 0          0.265238  0.084746          0.386161           0.005557
# 1          0.963452  0.186441          0.162946           0.004552
# 2          0.057619  0.186441          0.162946           0.002431
# 3          0.063810  0.084746          0.162946           0.011060
# 4          0.021310  0.084746          0.386161           0.012811
# ...             ...       ...               ...                ...
# 29995      0.397381  0.186441          0.162946           0.007513
# 29996      0.071905  0.389831          0.079241           0.003552
# 29997      0.183214  0.084746          0.386161           0.016557
# 29998      0.408810  0.186441          0.162946           0.002171
# 29999      0.408095  0.186441          0.162946           0.007513
#
#        state_bottle_retail  bottles_sold  sale_dollars  volume_sold_liters  \
# 0                 0.005556      0.003706      0.005651            0.004436
# 1                 0.004552      0.000741      0.001504            0.000626
# 2                 0.002431      0.001483      0.001287            0.000944
# 3                 0.011058      0.003706      0.010919            0.001896
# 4                 0.012809      0.012602      0.037965            0.013325
# ...                    ...           ...           ...                 ...
# 29995             0.007513      0.008154      0.015144            0.003801
# 29996             0.003552      0.000741      0.001185            0.000309
# 29997             0.016557      0.003706      0.016182            0.004436
# 29998             0.002171      0.008154      0.004920            0.003801
# 29999             0.007513      0.008154      0.015144            0.003801
#
#        year  month  category_name_freq_encoded  county_freq_encoded  \
# 0      2021      3                         726                  822
# 1      2024      4                         784                  125
# 2      2024     10                         726                 2560
# 3      2021     10                         726                  289
# 4      2020      7                         266                 1448
# ...     ...    ...                         ...                  ...
# 29995  2022      8                         838                  403
# 29996  2022      9                         386                  287
# 29997  2023      6                        2775                 5756
# 29998  2020     10                        2775                  975
# 29999  2023      5                         838                  975
#
#        vendor_name_freq_encoded
# 0                          2276
# 1                          1585
# 2                          2021
# 3                           132
# 4                          1235
# ...                         ...
# 29995                       959
# 29996                      1585
# 29997                      4494
# 29998                      2276
# 29999                       959
#
# [29975 rows x 13 columns]

# %%
x = df[[
    'store_number', 'pack', 'bottle_volume_ml', 'state_bottle_cost',
    'state_bottle_retail', 'bottles_sold', 'volume_sold_liters',
    'year', 'month', 'category_name_freq_encoded',
    'county_freq_encoded', 'vendor_name_freq_encoded'
]]
y = df['sale_dollars']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
x_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Step 5: Machine Learning Algorithms
# ### ~ Dataset Characteristics
# - **Goal:** Predict income_bracket (binary classification: <=50K or >50K).
# - **Features:**
# Mix of numerical (e.g., age, hours_per_week) and categorical (e.g., workclass, occupation) data.
# Some features (e.g., capital_gain and capital_loss) have skewed distributions or high sparsity.
# - **The target is imbalanced:** typically, fewer people earn >50K.
#
# ## 1. multiple Linear Regression
# **Why??**
# - Works well for binary classification.
# - Performs efficiently on structured datasets with preprocessed data.
# - Handles imbalanced classes reasonably well when combined with class weights or balancing techniques.

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.00014200341757127202

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 0.011916518685055296

# %%
n = X_test.shape[0]  # Number of samples
p = X_test.shape[1]  # Number of predictors
r2_adjusted = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
r2_adjusted
# Out:
# 0.7612446042186177

# %%
coefficients = pd.DataFrame({
    'Feature': x.columns,
    'Coefficient': model.coef_
})
coefficients
# Out:
#                        Feature   Coefficient
# 0                 store_number -1.858197e-03
# 1                         pack -2.187144e-02
# 2             bottle_volume_ml -7.075450e-03
# 3            state_bottle_cost -9.272860e+00
# 4          state_bottle_retail  9.564822e+00
# 5                 bottles_sold  5.233096e-01
# 6           volume_sold_liters  8.282717e-01
# 7                         year  1.018061e-04
# 8                        month  2.524568e-05
# 9   category_name_freq_encoded -5.137600e-07
# 10         county_freq_encoded  1.846599e-07
# 11    vendor_name_freq_encoded -2.183909e-08
